# %%
# installing matplotlib

# %%
pip install matplotlib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.2/162.2 kB 202.4 kB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 164.2 kB/s eta 0:00:0000:0100:02
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 245.3/245.3 kB 195.1 kB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 303.5 kB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.0/65.0 kB 434.2 kB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.2/103.2 kB 352.4 kB/s eta 0:00:00a 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install scipy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 537.9 kB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.1/23.1 MB 376.6 kB/s eta 0:00:0000:0100:02
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import necessary libraries

import matplotlib.pyplot as plt
import numpy as np
from scipy import stats

# %%
# Sample data for the charts

x = np.linspace(0, 10, 100)
y = np.sin(x)
data = [10, 20, 30, 40, 50]
categories = ['A', 'B', 'C', 'D', 'E']

# %%
# Line Chart

plt.figure(figsize=(10, 5))  
plt.plot(x, y, label='Sine Wave', color='blue', linestyle='-', linewidth=2)
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.title('Line Chart')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Bar Chart

plt.figure(figsize=(10, 5))
plt.bar(categories, data, color='green')
plt.xlabel('Categories')
plt.ylabel('Values')
plt.title('Bar Chart')
plt.grid(True)
plt.show()

# %%
# Pie Chart

plt.figure(figsize=(8, 8))
plt.pie(data, labels=categories, colors=['red', 'green', 'blue', 'yellow', 'purple'], 
        explode=[0, 0.1, 0, 0, 0], shadow=True, startangle=140, autopct='%1.1f%%')
plt.title('Pie Chart')
plt.show()

# %%
# Histogram

plt.figure(figsize=(10, 5))
data_hist = np.random.randn(1000)
plt.hist(data_hist, bins=30, color='blue', alpha=0.7)
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Histogram')
plt.grid(True)
plt.show()

# %%
# Scatter Plot

plt.figure(figsize=(10, 5))
x_scatter = np.random.rand(50)
y_scatter = np.random.rand(50)
plt.scatter(x_scatter, y_scatter, color='red')
plt.xlabel('X Value')
plt.ylabel('Y Value')
plt.title('Scatter Plot')
plt.grid(True)
plt.show()

# %%
# Area Chart

plt.figure(figsize=(10, 5))
plt.fill_between(x, y, color='orange', alpha=0.5)
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.title('Area Chart')
plt.grid(True)
plt.show()

# %%
# Box Plot
plt.figure(figsize=(10, 5))
data_box = [np.random.randn(100) for _ in range(5)]
plt.boxplot(data_box, patch_artist=True, 
            boxprops=dict(facecolor='cyan', color='blue'), 
            whiskerprops=dict(color='blue'),
            medianprops=dict(color='red'))
plt.xlabel('Categories')
plt.ylabel('Values')
plt.title('Box Plot')
plt.grid(True)
plt.show()
